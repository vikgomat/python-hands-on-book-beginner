# %% [markdown]
# <a href="https://colab.research.google.com/github/vikgomat/python-hands-on-book-beginner/blob/main/scraper_embedded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Script to clone quality embedded repos
import subprocess

repos = [
    "esp-idf",  # ESP32
    "stm32-examples",  # STM32
    "zephyr",  # RTOS
    "freertos",
    # Add more...
]

for repo in repos:
    subprocess.run(["git", "clone", f"https://github.com/.../{repo}"])

# %%
# Use tree-sitter to extract C functions
from tree_sitter import Language, Parser

# Parse .c files and extract function definitions
# Filter for embedded patterns (HAL_, GPIO_, UART_, etc.)
